# %%
#import needed modules
import pandas as pd
import numpy as np
import sklearn
import matplotlib as plt

# %%
col_names= [ 'patient', 'Age','Partner_Score','Self_Score','P_S','victim','PH_Score','PY_Score','E_Score','S_Score']

# %%
#importing first model-survey results
m1 = pd.read_csv("model - m1.csv", header= 0, names= col_names)

#iporting 2nd model-survey results
m2 = pd.read_csv("model - m2.csv", header= 0, names= col_names)

# %%
vict=pd.concat([m1,m2])

# %%
#verify merge
vict.head()
# Out:
#    patient  Age  Partner_Score  Self_Score  P_S victim  PH_Score  PY_Score  \
# 0        1   35              2           2    4    Yes         5         2
# 1        2   38              0           5    5    Yes         1         6
# 2        3   20              1           1    2    Yes         6         0
# 3        4   16              2           5    7    Yes         2         5
# 4        5   34              5           2    7    Yes         3         4
#
#    E_Score  S_Score
# 0        2        0
# 1        4        5
# 2        0        4
# 3        4        4
# 4        6        6

# %%
vict.corr()
# Out:
#                 patient       Age  Partner_Score  Self_Score       P_S  \
# patient        1.000000 -0.059528      -0.305124   -0.479716 -0.533727
# Age           -0.059528  1.000000       0.005412    0.062258  0.047668
# Partner_Score -0.305124  0.005412       1.000000    0.106541  0.707531
# Self_Score    -0.479716  0.062258       0.106541    1.000000  0.778042
# P_S           -0.533727  0.047668       0.707531    0.778042  1.000000
# PH_Score      -0.426332 -0.031748       0.128453    0.327022  0.313581
# PY_Score      -0.380836  0.020260       0.101259    0.264606  0.252039
# E_Score       -0.240938  0.003736       0.165627    0.015809  0.115881
# S_Score       -0.327583 -0.015922       0.163475    0.135486  0.199579
#
#                PH_Score  PY_Score   E_Score   S_Score
# patient       -0.426332 -0.380836 -0.240938 -0.327583
# Age           -0.031748  0.020260  0.003736 -0.015922
# Partner_Score  0.128453  0.101259  0.165627  0.163475
# Self_Score     0.327022  0.264606  0.015809  0.135486
# P_S            0.313581  0.252039  0.115881  0.199579
# PH_Score       1.000000  0.199508  0.106011  0.173917
# PY_Score       0.199508  1.000000  0.105377  0.252579
# E_Score        0.106011  0.105377  1.000000  0.243623
# S_Score        0.173917  0.252579  0.243623  1.000000

# %%
import seaborn as sns
sns.countplot(vict['victim'],label="Count")
plt
# Out:
# <module 'matplotlib' from '/opt/tljh/user/lib/python3.6/site-packages/matplotlib/__init__.py'>

# %%
#convert victim dtype to category from object in order to encode
vict["victim"] = vict["victim"].astype('category')

# %%
#recode victim column
#label encoder column victim
vict["victim_cat"] = vict["victim"].cat.codes

# %%
from pandas.tools.plotting import scatter_matrix
from matplotlib import cm
feature_names = ['Age', 'Partner_Score', 'Self_Score','P_S', 'PH_Score','PY_Score','E_Score','S_Score']
X = vict[feature_names]
y = vict['victim_cat']
cmap = cm.get_cmap('gnuplot')
scatter = pd.scatter_matrix(X, c = y, marker = 'o', s=10, hist_kwds={'bins':15}, figsize=(9,9), cmap = cmap)
plt.subtitle('Scatter-matrix for each input variable')
plt.savefig('victim_scatter_matrix')
# Out:
# /opt/tljh/user/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   import sys
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-209-8ff3b557314e> in <module>
#       6 cmap = cm.get_cmap('gnuplot')
#       7 scatter = pd.scatter_matrix(X, c = y, marker = 'o', s=10, hist_kwds={'bins':15}, figsize=(9,9), cmap = cmap)
# ----> 8 plt.subtitle('Scatter-matrix for each input variable')
#       9 plt.savefig('victim_scatter_matrix')
#
# AttributeError: module 'matplotlib' has no attribute 'subtitle'

# %%
vict.corr()
# Out:
#                 patient       Age  Partner_Score  Self_Score       P_S  \
# patient        1.000000 -0.059528      -0.305124   -0.479716 -0.533727
# Age           -0.059528  1.000000       0.005412    0.062258  0.047668
# Partner_Score -0.305124  0.005412       1.000000    0.106541  0.707531
# Self_Score    -0.479716  0.062258       0.106541    1.000000  0.778042
# P_S           -0.533727  0.047668       0.707531    0.778042  1.000000
# PH_Score      -0.426332 -0.031748       0.128453    0.327022  0.313581
# PY_Score      -0.380836  0.020260       0.101259    0.264606  0.252039
# E_Score       -0.240938  0.003736       0.165627    0.015809  0.115881
# S_Score       -0.327583 -0.015922       0.163475    0.135486  0.199579
# victim_cat    -0.389267  0.010667       0.438666    0.588091  0.695126
#
#                PH_Score  PY_Score   E_Score   S_Score  victim_cat
# patient       -0.426332 -0.380836 -0.240938 -0.327583   -0.389267
# Age           -0.031748  0.020260  0.003736 -0.015922    0.010667
# Partner_Score  0.128453  0.101259  0.165627  0.163475    0.438666
# Self_Score     0.327022  0.264606  0.015809  0.135486    0.588091
# P_S            0.313581  0.252039  0.115881  0.199579    0.695126
# PH_Score       1.000000  0.199508  0.106011  0.173917    0.235000
# PY_Score       0.199508  1.000000  0.105377  0.252579    0.180686
# E_Score        0.106011  0.105377  1.000000  0.243623    0.081528
# S_Score        0.173917  0.252579  0.243623  1.000000    0.175391
# victim_cat     0.235000  0.180686  0.081528  0.175391    1.000000

# %% [markdown]
# Age shows the lowest correlation with victim catergory. This addresses the exploratory objetive pertaining to whether or not age is a factor in oe being more susceptible to being a victime of domestic violence. Additionally some o the particpints were identified as victim in the prescreening section but later identified as a type of victim when they answered questions regarding the four different type of abuse. Partner_Score and Self_SCore have a higher correlation with victim category compred to PH_Score, PY_SCore, E_SCore and S_Score. P_S score has the highest correlation because it is the sum of Partner_Score and SElf_SCore. The rule I generated was that in order to identify a victim as Yes, No or Unknown t would be based on the score of both the Partner and Self. The four abuse types are not mutually exclusive thus a patient could be identified as more than one type of abuse victim. Due to the special condition of each abuse type further assessment would be required which is why the next step of this capstone requires dropping all four abuse types. After patient has been identified the referral method is to a dometic violence center which enables further victim assessment.

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
#Feature Importance among the variables using ExtraTreesClassifier
model = ExtraTreesClassifier(n_estimators=100)
model.fit(X,y)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
#Check the top 3 features with highest score
feat_importances.nlargest(5).plot(kind='barh')
plt.title('Top 5 most important features')
plt.show()
# Out:
# [0.04367779 0.16200057 0.22001461 0.37968967 0.06012739 0.04267882
#  0.04376867 0.04804248]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-216-27db69f78f9f> in <module>
#       8 #Check the top 3 features with highest score
#       9 feat_importances.nlargest(5).plot(kind='barh')
# ---> 10 plt.title('Top 5 most important features')
#      11 plt.show()
#
# AttributeError: module 'matplotlib' has no attribute 'title'

# %%
#drop last 4 columns in new df
#create new df to only identify victim = yes / no/unknown
vict1= vict.drop(columns=['patient','PH_Score','PY_Score','E_Score','S_Score'], axis=0)

# %%
#verify colunms succefully dropped
vict1.head()
# Out:
#    Age  Partner_Score  Self_Score  P_S victim  victim_cat
# 0   35              2           2    4    Yes           2
# 1   38              0           5    5    Yes           2
# 2   20              1           1    2    Yes           2
# 3   16              2           5    7    Yes           2
# 4   34              5           2    7    Yes           2

# %%
vict1.describe()
# Out:
#               Age  Partner_Score  Self_Score         P_S  victim_cat
# count  200.000000      200.00000  200.000000  200.000000  200.000000
# mean    32.735000        1.32000    1.315000    2.635000    1.670000
# std     10.215998        2.72299    3.063117    4.309832    0.576857
# min     14.000000       -5.00000   -5.000000   -9.000000    0.000000
# 25%     24.000000        0.00000   -1.000000    0.000000    1.000000
# 50%     33.000000        2.00000    2.000000    3.000000    2.000000
# 75%     41.000000        3.25000    4.000000    6.000000    2.000000
# max     50.000000        5.00000    5.000000   10.000000    2.000000

# %%
vict1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 0 to 99
# Data columns (total 5 columns):
# Age              200 non-null int64
# Partner_Score    200 non-null int64
# Self_Score       200 non-null int64
# P_S              200 non-null int64
# victim_cat       200 non-null int8
# dtypes: int64(4), int8(1)
# memory usage: 13.0 KB

# %%
#print shape of new data
print(vict1.shape)
# Out:
# (200, 5)

# %%
feature_names = ['Age', 'Partner_Score', 'Self_Score', 'P_S']
X = vict1[feature_names]
y = vict1['victim_cat']

# %%
#Feature Importance among the variables using ExtraTreesClassifier
model = ExtraTreesClassifier(n_estimators=100)
model.fit(X,y)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
#Check the top 3 features with highest score
feat_importances.nlargest(3).plot(kind='barh')
plt.title('Top 3 most important features')
plt.show()
# Out:
# [0.04192867 0.18682418 0.23934102 0.53190613]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-243-c643a8e6e62e> in <module>
#       7 #Check the top 3 features with highest score
#       8 feat_importances.nlargest(3).plot(kind='barh')
# ----> 9 plt.title('Top 3 most important features')
#      10 plt.show()
#
# AttributeError: module 'matplotlib' has no attribute 'title'

# %%
#verify successful encoding
vict1.head()
#drop column victim to have all int64 dtype
vict1= vict1.drop(columns=['victim'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-244-a2e9e2111749> in <module>
#       2 vict1.head()
#       3 #drop column victim to have all int64 dtype
# ----> 4 vict1= vict1.drop(columns=['victim'])
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3141                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3142             else:
# -> 3143                 new_axis = axis.drop(labels, errors=errors)
#    3144             result = self.reindex(**{axis_name: new_axis})
#    3145
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4402             if errors != 'ignore':
#    4403                 raise KeyError(
# -> 4404                     '{} not found in axis'.format(labels[mask]))
#    4405             indexer = indexer[~mask]
#    4406         return self.delete(indexer)
#
# KeyError: "['victim'] not found in axis"

# %%
#verify victim column was successfully dropped
#verify dtype int64 for all
vict1.head()
# Out:
#    Age  Partner_Score  Self_Score  P_S  victim_cat
# 0   35              2           2    4           2
# 1   38              0           5    5           2
# 2   20              1           1    2           2
# 3   16              2           5    7           2
# 4   34              5           2    7           2

# %%
from pandas.tools.plotting import scatter_matrix
from matplotlib import cm
feature_names = ['Age', 'Partner_Score', 'Self_Score','P_S']
X = vict1[feature_names]
y = vict1['victim_cat']
cmap = cm.get_cmap('gnuplot')
scatter = pd.scatter_matrix(X, c = y, marker = 'o', s=30, hist_kwds={'bins':15}, figsize=(10,10), cmap = cmap)
plt.subtitle('Scatter-matrix for each input variable')
plt.savefig('victim_scatter_matrix')
# Out:
# /opt/tljh/user/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   import sys
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-246-21846a593ffd> in <module>
#       6 cmap = cm.get_cmap('gnuplot')
#       7 scatter = pd.scatter_matrix(X, c = y, marker = 'o', s=30, hist_kwds={'bins':15}, figsize=(10,10), cmap = cmap)
# ----> 8 plt.subtitle('Scatter-matrix for each input variable')
#       9 plt.savefig('victim_scatter_matrix')
#
# AttributeError: module 'matplotlib' has no attribute 'subtitle'

# %%
vict1.corr()
# Out:
#                     Age  Partner_Score  Self_Score       P_S  victim_cat
# Age            1.000000       0.005412    0.062258  0.047668    0.010667
# Partner_Score  0.005412       1.000000    0.106541  0.707531    0.438666
# Self_Score     0.062258       0.106541    1.000000  0.778042    0.588091
# P_S            0.047668       0.707531    0.778042  1.000000    0.695126
# victim_cat     0.010667       0.438666    0.588091  0.695126    1.000000

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()

# %%
#assign label for decision tree
feature_names = ['Age', 'Partner_Score', 'Self_Score','P_S']
class_names= ['Yes','No','Unknown']
#assign feature variables to x
X = vict1[feature_names]
#assign target variable to y
y = vict1['victim_cat']

# %%
clf = clf.fit(X,y)

# %%
tree.plot_tree(clf.fit(X,y))
# Out:
# [Text(167.4, 199.32, 'X[3] <= 0.5\nentropy = 0.423\nsamples = 200\nvalue = [11, 44, 145]'),
#  Text(83.7, 163.07999999999998, 'X[3] <= -0.5\nentropy = 0.338\nsamples = 51\nvalue = [11, 40, 0]'),
#  Text(41.85, 126.83999999999999, 'entropy = 0.0\nsamples = 40\nvalue = [0, 40, 0]'),
#  Text(125.55000000000001, 126.83999999999999, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0, 0]'),
#  Text(251.10000000000002, 163.07999999999998, 'X[3] <= 1.5\nentropy = 0.052\nsamples = 149\nvalue = [0, 4, 145]'),
#  Text(209.25, 126.83999999999999, 'X[2] <= 2.5\nentropy = 0.408\nsamples = 14\nvalue = [0, 4, 10]'),
#  Text(167.4, 90.6, 'X[1] <= 2.5\nentropy = 0.5\nsamples = 8\nvalue = [0, 4, 4]'),
#  Text(125.55000000000001, 54.359999999999985, 'X[0] <= 19.5\nentropy = 0.32\nsamples = 5\nvalue = [0, 4, 1]'),
#  Text(83.7, 18.119999999999976, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(167.4, 18.119999999999976, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4, 0]'),
#  Text(209.25, 54.359999999999985, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(251.10000000000002, 90.6, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 6]'),
#  Text(292.95, 126.83999999999999, 'entropy = 0.0\nsamples = 135\nvalue = [0, 0, 135]')]

# %% [markdown]
# ## Decision Tree

# %%
dot_data = tree.export_graphviz(clf, out_file=None, 
...                      feature_names=feature_names,  
...                      class_names=class_names,  
...                      filled=True, rounded=True,  
...                      special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %%
#verify if data is balanced
print(vict1.groupby('victim_cat').size())
# Out:
# victim_cat
# 0     11
# 1     44
# 2    145
# dtype: int64

# %% [markdown]
# ### Victim identified = No (11)
# ### Victime identified= Unknown (44)
# ### Victim identified= Yes (145)
